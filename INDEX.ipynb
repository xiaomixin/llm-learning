# %% [markdown]
# # 📚 llm-learning — Notebook Index
#
# 所有 notebooks 一览。点击 **Open in Colab** 直接在 Colab 打开（走 GitHub 集成）。
#
# | Week | Notebook | Open in Colab |
# |------|----------|---------------|
# | 01 | `env_check.ipynb` — 环境自检 | [![Open](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/xiaomixin/llm-learning/blob/main/week01/env_check.ipynb) |
# | 01 | `01_eda.ipynb` — Kaggle Credit Card Fraud EDA | [![Open](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/xiaomixin/llm-learning/blob/main/week01/01_eda.ipynb) |
# | — | `templates/notebook_template.ipynb` — 新 notebook 模板 | [![Open](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/xiaomixin/llm-learning/blob/main/templates/notebook_template.ipynb) |
#
# ---
#
# ## 🔄 Sync 工作流速查
#
# - **本地 → Drive / Colab**：`git commit` 后 post-commit hook 自动跑 `scripts/sync_to_drive.sh push`
# - **Colab → 本地**：本地跑 `scripts/watch_drive.sh`（`brew install fswatch`），改动自动拉回
# - **手动触发**：`bash scripts/sync_to_drive.sh [push|pull|diff]`
#
# ## 🔑 Colab Secrets（一次性）
#
# 左侧 🔑 图标：`KAGGLE_USERNAME` / `KAGGLE_KEY`。永远别把 `kaggle.json` 上传或提交。
#
# ## 📖 主计划
#
# [`transformer-12week-plan.md`](https://github.com/xiaomixin/llm-learning/blob/main/transformer-12week-plan.md) —— 12 周 × 10h 详细拆解。

# %%
# 在 Colab 内直接列出所有 notebook（自动挂 Drive）
import os, sys, pathlib

if 'google.colab' in sys.modules:
    from google.colab import drive
    if not os.path.exists('/content/drive'):
        drive.mount('/content/drive')
    ROOT = pathlib.Path('/content/drive/MyDrive/LLM/transformer-anomaly')
else:
    ROOT = pathlib.Path.cwd()

if not ROOT.exists():
    raise FileNotFoundError(f'{ROOT} 不存在。确认 sync_to_drive.sh push 已跑过，或 Colab 已挂 Drive。')

print(f'📂 {ROOT}\n')
for p in sorted(ROOT.rglob('*.ipynb')):
    if '.ipynb_checkpoints' in p.parts: continue
    print(' ', p.relative_to(ROOT))
